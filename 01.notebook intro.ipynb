# %% [markdown]
# this is the doc cell
# # header1
# # header1
# ## header2
# ### header3
# - bullet 1
# - bullet 2

# %%
print ('hello')
print('bye')

# %%
# %sql
select 'hello from sql'

# %%
# %fs ls /databricks-datasets/

# %%
# %sh ps

# %%
# %pip install faker
