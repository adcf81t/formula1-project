# %%
# %sql
--drop schema f1_presentation cascade

# %%
# %sql
create database if not exists f1_presentation
location "/mnt/formula1dl4dbcourse/presentation"

# %%
# %sql desc database f1_presentation
