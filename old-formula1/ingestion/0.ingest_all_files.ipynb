# %%
v_result = dbutils.notebook.run("1.ingest_circuit_files", 0, {"p_data_source": "Ergast API"})

# %%
v_result

# %%
v_result = dbutils.notebook.run("2.ingest_races_file", 0)
v_result

# %%
v_result = dbutils.notebook.run("3.ingest_constructors_file", 0)
v_result

# %%
v_result = dbutils.notebook.run("4.ingest_drivers_file", 0)

v_result

# %%
dbutils.notebook.run("5.ingest_results_file", 0)
dbutils.notebook.run("6.ingest_pit_stops_file", 0)
dbutils.notebook.run("7.ingest_lap_times_file", 0)
dbutils.notebook.run("8.ingest_qualifying_file", 0)
