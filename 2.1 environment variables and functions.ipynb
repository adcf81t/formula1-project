# %%
env ='dev'

# %%
import os
import platform
def print_env_info():
    #print python version
    print("Python version: ", platform.python_version())
    #print spark version
    print("Spark version: ", spark.version)
    #print databricks runtime version
    print("Databricks runtime version: ", os.environ['DATABRICKS_RUNTIME_VERSION'])

print_env_info()
